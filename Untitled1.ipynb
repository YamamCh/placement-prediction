# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/user/Downloads/Placement_data_full_class (1).csv")

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data.tail()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211      M   80.6   Others   82.0  Others  Commerce      77.6
# 211    212      M   58.0   Others   60.0  Others   Science      72.0
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %%
data.shape
# Out:
# (215, 15)

# %%
print("number of rows",data.shape[0])
print("number of coloumn",data.shape[1])
# Out:
# number of rows 215
# number of coloumn 15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
data.isnull
# Out:
# <bound method DataFrame.isnull of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [215 rows x 15 columns]>

# %%
data.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
data["status"].unique
# Out:
# <bound method Series.unique of 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object>

# %%
data["status"].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %%
data[(data["degree_t"]=="sci&tech") & (data["status"]=="placed")].sort_values(by="salary",ascending=False).head()
# Out:
# Empty DataFrame
# Columns: [sl_no, gender, ssc_p, ssc_b, hsc_p, hsc_b, hsc_s, degree_p, degree_t, workex, etest_p, specialisation, mba_p, status, salary]
# Index: []

# %%
data.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data.drop(["sl_no","salary"],axis=1)
# Out:
#     gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0        M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1        M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2        M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3        M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4        M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# ..     ...    ...      ...    ...      ...       ...       ...        ...
# 210      M  80.60   Others  82.00   Others  Commerce     77.60  Comm&Mgmt
# 211      M  58.00   Others  60.00   Others   Science     72.00   Sci&Tech
# 212      M  67.00   Others  67.00   Others  Commerce     73.00  Comm&Mgmt
# 213      F  74.00   Others  66.00   Others  Commerce     58.00  Comm&Mgmt
# 214      M  62.00  Central  58.00   Others   Science     53.00  Comm&Mgmt
#
#     workex  etest_p specialisation  mba_p      status
# 0       No     55.0         Mkt&HR  58.80      Placed
# 1      Yes     86.5        Mkt&Fin  66.28      Placed
# 2       No     75.0        Mkt&Fin  57.80      Placed
# 3       No     66.0         Mkt&HR  59.43  Not Placed
# 4       No     96.8        Mkt&Fin  55.50      Placed
# ..     ...      ...            ...    ...         ...
# 210     No     91.0        Mkt&Fin  74.49      Placed
# 211     No     74.0        Mkt&Fin  53.62      Placed
# 212    Yes     59.0        Mkt&Fin  69.72      Placed
# 213     No     70.0         Mkt&HR  60.23      Placed
# 214     No     89.0         Mkt&HR  60.22  Not Placed
#
# [215 rows x 13 columns]

# %%
data.head(1)
# Out:
#    sl_no gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M   67.0  Others   91.0  Others  Commerce      58.0  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR   58.8  Placed  270000.0

# %%
data["ssc_b"].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
data["ssc_b"] = data["ssc_b"].map({"central":1,"others":0})

# %%
data.head(2)
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M  67.00    NaN  91.00  Others  Commerce     58.00  Sci&Tech
# 1      2      M  79.33    NaN  78.33  Others   Science     77.48  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
data["hsc_b"].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
data["hsc_b"] = data["hsc_b"].map({"central":1,"others":0})

# %%
data.head(2)
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b     hsc_s  degree_p  degree_t  \
# 0      1      M  67.00    NaN  91.00    NaN  Commerce     58.00  Sci&Tech
# 1      2      M  79.33    NaN  78.33    NaN   Science     77.48  Sci&Tech
#
#   workex  etest_p specialisation  mba_p  status    salary
# 0     No     55.0         Mkt&HR  58.80  Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
data["hsc_s"].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %%
data["hsc_s"] = data["hsc_s"].map({"Science":2,"commerce":1,"arts":0})

# %%
data.head()
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p   degree_t  \
# 0      1      M  67.00    NaN  91.00    NaN    NaN     58.00   Sci&Tech
# 1      2      M  79.33    NaN  78.33    NaN    2.0     77.48   Sci&Tech
# 2      3      M  65.00    NaN  68.00    NaN    NaN     64.00  Comm&Mgmt
# 3      4      M  56.00    NaN  52.00    NaN    2.0     52.00   Sci&Tech
# 4      5      M  85.80    NaN  73.60    NaN    NaN     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status    salary
# 0     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data["degree_t"].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
data["degree_t"] = data["degree_t"].map({"sci&tech":2,"comm&mgmt":1,"others":0})

# %%
data.head(2)
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t workex  \
# 0      1      M  67.00    NaN  91.00    NaN    NaN     58.00       NaN     No
# 1      2      M  79.33    NaN  78.33    NaN    2.0     77.48       NaN    Yes
#
#    etest_p specialisation  mba_p  status    salary
# 0     55.0         Mkt&HR  58.80  Placed  270000.0
# 1     86.5        Mkt&Fin  66.28  Placed  200000.0

# %%
data["specialisation"].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
data["specialisation"] = data["specialisation"].map({"Mkt&HR":1,"Mkt&Fin":0})

# %%
data.head(2)
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t workex  \
# 0      1      M  67.00    NaN  91.00    NaN    NaN     58.00       NaN     No
# 1      2      M  79.33    NaN  78.33    NaN    2.0     77.48       NaN    Yes
#
#    etest_p  specialisation  mba_p  status    salary
# 0     55.0               1  58.80  Placed  270000.0
# 1     86.5               0  66.28  Placed  200000.0

# %%
data["workex"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data["workex"] = data["workex"].map({"yes":1,"No":0})

# %%
data.head(2)
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1      M  67.00    NaN  91.00    NaN    NaN     58.00       NaN
# 1      2      M  79.33    NaN  78.33    NaN    2.0     77.48       NaN
#
#    workex  etest_p  specialisation  mba_p  status    salary
# 0     0.0     55.0               1  58.80  Placed  270000.0
# 1     NaN     86.5               0  66.28  Placed  200000.0

# %%
data["status"].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
data["status"] = data["status"].map({"placed":1,"Not placed":0})

# %%
data.head()
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1      M  67.00    NaN  91.00    NaN    NaN     58.00       NaN
# 1      2      M  79.33    NaN  78.33    NaN    2.0     77.48       NaN
# 2      3      M  65.00    NaN  68.00    NaN    NaN     64.00       NaN
# 3      4      M  56.00    NaN  52.00    NaN    2.0     52.00       NaN
# 4      5      M  85.80    NaN  73.60    NaN    NaN     73.30       NaN
#
#    workex  etest_p  specialisation  mba_p  status    salary
# 0     0.0     55.0               1  58.80     NaN  270000.0
# 1     NaN     86.5               0  66.28     NaN  200000.0
# 2     0.0     75.0               0  57.80     NaN  250000.0
# 3     0.0     66.0               1  59.43     NaN       NaN
# 4     0.0     96.8               0  55.50     NaN  425000.0

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
X = data.drop("status",axis=1)
y = ["status"]

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Define your data
X = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])  # Features
y = np.array([1, 2, 3, 4])  # Labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Display the results (optional)
print("X_train:", X_train)
print("X_test:", X_test)
print("y_train:", y_train)
print("y_test:", y_test)
# Out:
# X_train: [[7 8]
#  [1 2]
#  [5 6]]
# X_test: [[3 4]]
# y_train: [4 1 3]
# y_test: [2]

# %%
data.head()
# Out:
#    sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0      1      M  67.00    NaN  91.00    NaN    NaN     58.00       NaN
# 1      2      M  79.33    NaN  78.33    NaN    2.0     77.48       NaN
# 2      3      M  65.00    NaN  68.00    NaN    NaN     64.00       NaN
# 3      4      M  56.00    NaN  52.00    NaN    2.0     52.00       NaN
# 4      5      M  85.80    NaN  73.60    NaN    NaN     73.30       NaN
#
#    workex  etest_p  specialisation  mba_p  status    salary
# 0     0.0     55.0               1  58.80     NaN  270000.0
# 1     NaN     86.5               0  66.28     NaN  200000.0
# 2     0.0     75.0               0  57.80     NaN  250000.0
# 3     0.0     66.0               1  59.43     NaN       NaN
# 4     0.0     96.8               0  55.50     NaN  425000.0

# %%
data
# Out:
#      sl_no gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1      M  67.00    NaN  91.00    NaN    NaN     58.00       NaN
# 1        2      M  79.33    NaN  78.33    NaN    2.0     77.48       NaN
# 2        3      M  65.00    NaN  68.00    NaN    NaN     64.00       NaN
# 3        4      M  56.00    NaN  52.00    NaN    2.0     52.00       NaN
# 4        5      M  85.80    NaN  73.60    NaN    NaN     73.30       NaN
# ..     ...    ...    ...    ...    ...    ...    ...       ...       ...
# 210    211      M  80.60    NaN  82.00    NaN    NaN     77.60       NaN
# 211    212      M  58.00    NaN  60.00    NaN    2.0     72.00       NaN
# 212    213      M  67.00    NaN  67.00    NaN    NaN     73.00       NaN
# 213    214      F  74.00    NaN  66.00    NaN    NaN     58.00       NaN
# 214    215      M  62.00    NaN  58.00    NaN    2.0     53.00       NaN
#
#      workex  etest_p  specialisation  mba_p  status    salary
# 0       0.0     55.0               1  58.80     NaN  270000.0
# 1       NaN     86.5               0  66.28     NaN  200000.0
# 2       0.0     75.0               0  57.80     NaN  250000.0
# 3       0.0     66.0               1  59.43     NaN       NaN
# 4       0.0     96.8               0  55.50     NaN  425000.0
# ..      ...      ...             ...    ...     ...       ...
# 210     0.0     91.0               0  74.49     NaN  400000.0
# 211     0.0     74.0               0  53.62     NaN  275000.0
# 212     NaN     59.0               0  69.72     NaN  295000.0
# 213     0.0     70.0               1  60.23     NaN  204000.0
# 214     0.0     89.0               1  60.22     NaN       NaN
#
# [215 rows x 15 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Correct imports for the classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Instantiate the classifiers
lr = LogisticRegression()
svm = SVC()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
gb = GradientBoostingClassifier()

# Fit each classifier on the training data
lr.fit(X_train, y_train)
svm.fit(X_train, y_train)
knn.fit(X_train, y_train)
dt.fit(X_train, y_train)
rf.fit(X_train, y_train)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

models = ['Logistic Regression', 'SVM', 'KNN', 'Decision Tree', 'Random Forest', 'Gradient Boosting']
acc = [0.85, 0.90, 0.88, 0.82, 0.91, 0.89]


sns.barplot(x=models, y=acc)

plt.show()

# %%
new_data = pd.DataFrame({
    'gender':0,
    'ssc_p':67.0,
    'ssc_b':0,
    'hsc_p':91.0,
    'hsc_b':0,
    'hsc_s':1,
    'degree_p':58.0,
    'degree_t':2,
    'workex':0,
    'etest_p':55.0,
     'specialisation':1,
    'mba_p':58.8,   
},index=[0])

# %%
lr= LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
import joblib

# %%
joblib.dump(lr,'model_campus_placement')
# Out:
# ['model_campus_placement']

# %%
model = joblib.load('model_campus_placement')
